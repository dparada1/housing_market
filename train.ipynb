# %%
# Author : Daniel Parada

# Import the necessary packages
import import_ipynb
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

class df_train(object):
    """Trains a regression model. 
    
    Attributes :
        X : pandas.DataFrame containing the features describing the real states sold
        y : pandas.DataFrame containing the ground truth for the data
        
    Returns :
        trained regression model
    """
    
    def __init__(self, path_feat, path_truth, file_feat, file_truth, EDA = True):
        """Initialises df attribute of the class.
        
        Args :
            path_feat : String, path to the feature csv file
            path_truth : String, path to the ground truth csv file
            file_feat : String, name of the feature csv file
            file_truth : String, name of the ground truth csv file
            EDA : bool, whether or not to perform EDA on the training data
            
        Returns :
            None
        """
        
        self.X_train = pd.read_csv(path_feat + file_feat)
        self.y_train = pd.read_csv(path_truth + file_truth)
        self.EDA = EDA
        
    
    def df_train_model(self, model, all_models=False):
        """Trains a regretion model on the training data set
        
        Args :
            model : model used for regression
            all : bool, when true it trains all the models available
            
        Returns :
            trained model(s)
        """
        
        # Perform EDA on the training data set
        if EDA:
            df = pd.concat([self.X, self.y])
            df = df.drop('Id', axis=1)
            df = EDA(df)
            df.eda()
            
        if all_models:
            #TODO
            trained_models = model.fit(self.X_train, self.y_train)
        else:
            trained_model = model.fit(self.X_train, self.y_train)
            
        return trained_model

# %%
# train class test
path_feat = '/Users/danielparada/Documents/House_pricing/'
path_truth = '/Users/danielparada/Documents/House_pricing/'
file_feat = 'df_Train.csv'
file_truth = 'df_TrainGt.csv'
EDA = False
tmodel = df_train(path_feat, path_truth, file_feat, file_truth, EDA)


# tmodel.X_train.columns
# tmodel = df_train.df_train_model(tmodel, model=LinearRegression())

model = LinearRegression()
x_try = tmodel.X_train.select_dtypes(include='number')
y_try = tmodel.y_train.select_dtypes(include='number')

model.fit(x_try, y_try)

# tmodel.X_train.head(10)

# train_test = train(path_feat, path_truth, file_feat, file_truth, EDA)
# trained_model = df_train(model=model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-f4b39ed2af99> in <module>()
#      15 y_try = tmodel.y_train.select_dtypes(include='number')
#      16
# ---> 17 model.fit(x_try, y_try)
#      18
#      19 # tmodel.X_train.head(10)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...
